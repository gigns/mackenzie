# %% [markdown]
# <a href="https://colab.research.google.com/github/gigns/mackenzie/blob/main/Avaliacao_trilha1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PARADIGMAS DE LINGUAGEM DE PROGRAMAÇÃO EM CIÊNCIA DE DADOS [TURMA 01C] - 2022/1

# %% [markdown]
# Trilha 1: Tarefa (Peso 3)

# %% [markdown]
# O texto escolhido foi uma biblioteca JQuery usado comumente na criação de websites para facilitar o desenvolvimento dos mesmos adicionando interativadade

# %% [markdown]
# **AQUISIÇÃO DOS DADOS:**

# %%
import urllib.request  

texto = []

for line in urllib.request.urlopen('https://code.jquery.com/jquery-3.6.0.js'): 
    texto.append(line.decode('utf-8'))

# f = open('/kate_beckinsale.txt','r')    # para arquivos locais
# for line in f:
#    texto.append(line)

for i in range(len(texto)):
    texto[i] = texto[i].lower() # para unicidade
    texto[i] = texto[i].replace('\n','')
    texto[i] = texto[i].replace('.','')
    texto[i] = texto[i].replace(',','')
    texto[i] = texto[i].replace('(','')
    texto[i] = texto[i].replace(')','')
    texto[i] = texto[i].replace('?','')
    texto[i] = texto[i].replace('\'','') # elimina ' e "

# %% [markdown]
# **CONSTRUÇÃO DO DICIONÁRIO:**

# %%
mydict = {}                             # crie um dicionário vazio

for line in texto:

  line = line.lower()                   # converte para lower
  words = line.split()                  # separa cada palavra
#  print(words)

  for word in words:                      # para cada palavra em words
    if word not in mydict.keys():         # se palavra não está no dicionário 
      mydict[word] = 1                    # acrescenta a word com o valor 1
    else:                                 # se a entrada já existe 
      mydict[word] =  mydict[word] + 1    # apenas soma 1 ao valor já existente

print(mydict)
# Out:
# {'/*!': 2, '*': 110, 'jquery': 88, 'javascript': 1, 'library': 2, 'v360': 1, 'https://jquerycom/': 1, 'includes': 3, 'sizzlejs': 1, 'https://sizzlejscom/': 2, 'copyright': 2, 'openjs': 1, 'foundation': 2, 'and': 157, 'other': 14, 'contributors': 2, 'released': 2, 'under': 2, 'the': 507, 'mit': 2, 'license': 2, 'https://jqueryorg/license': 1, 'date:': 2, '2021-03-02t17:08z': 1, '*/': 47, 'function': 651, 'global': 20, 'factory': 7, '{': 1850, '"use': 2, 'strict";': 2, 'if': 1013, 'typeof': 87, 'module': 8, '===': 399, '"object"': 19, '&&': 415, 'moduleexports': 3, '//': 1721, 'for': 285, 'commonjs': 2, 'commonjs-like': 1, 'environments': 3, 'where': 10, 'a': 327, 'proper': 5, '`window`': 3, 'is': 179, 'present': 6, 'execute': 8, 'get': 40, 'that': 80, 'do': 19, 'not': 84, 'have': 39, 'with': 70, '`document`': 1, 'such': 10, 'as': 61, 'nodejs': 1, 'expose': 4, 'this': 217, 'accentuates': 1, 'need': 14, 'creation': 1, 'of': 123, 'real': 3, 'eg': 11, 'var': 328, '=': 1755, 'require"jquer
# ...

# %% [markdown]
# **EXIBIÇÃO DOS RESULTADOS:**

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 30] # somente termos com mais de 30 ocorrências
# df = df.iloc[ np.int(len(df)/2) - 10 : np.int(len(df)/2) + 10 ] # para livros ou textos com muitos termos limita a um número mínimo de termos

plt.figure(figsize=(24,10))
mpl.style.use(['seaborn'])
sns.barplot(x=df.word,y=df['count'])
plt.xticks(rotation=90) 

plt.show()

# %% [markdown]
# Os termos que aparecem com mais frequência são os sinais de abertura e fechamento de códigos e sinais condicionais e logo após aparecem termos como function ou return usados para definir uma função no bloco de código e return para retornar um resultado.
#
# **OBS: Foram contados termos com mais de 30 ocorrências para facilitar a visualização do resultado**
